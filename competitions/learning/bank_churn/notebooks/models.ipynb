# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier, early_stopping, Dataset
import lightgbm as lgb
from xgboost import XGBClassifier

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder


# Вспомогательные блоки организации для пайплайна
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn import set_config
import warnings
warnings.filterwarnings('ignore')
set_config(transform_output="pandas")

import optuna
from optuna.integration import CatBoostPruningCallback
from optuna.samplers import RandomSampler
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216 from C header, got 232 from PyObject

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../data/train.csv').drop(columns=['id'])
train
# Out:
#         CustomerId         Surname  ...  EstimatedSalary Exited
# 0         15674932  Okwudilichukwu  ...        181449.97      0
# 1         15749177   Okwudiliolisa  ...         49503.50      0
# 2         15694510           Hsueh  ...        184866.69      0
# 3         15741417             Kao  ...         84560.88      0
# 4         15766172       Chiemenam  ...         15068.83      0
# ...            ...             ...  ...              ...    ...
# 165029    15667085            Meng  ...        131834.75      0
# 165030    15665521       Okechukwu  ...        131834.45      0
# 165031    15664752            Hsia  ...        127429.56      0
# 165032    15689614          Hsiung  ...         71173.03      0
# 165033    15732798         Ulyanov  ...         61581.79      1
#
# [165034 rows x 13 columns]

# %% [markdown]
# ## Features

# %%
train_f = train.drop_duplicates(subset=['CustomerId', 'Surname']).drop(columns=['CustomerId', 'Surname'])
train_f
# Out:
#         CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0               668    France    Male  ...             0.0        181449.97       0
# 1               627    France    Male  ...             1.0         49503.50       0
# 2               678    France    Male  ...             0.0        184866.69       0
# 3               581    France    Male  ...             1.0         84560.88       0
# 4               716     Spain    Male  ...             1.0         15068.83       0
# ...             ...       ...     ...  ...             ...              ...     ...
# 165028          630    France    Male  ...             1.0          5962.50       0
# 165030          792    France    Male  ...             0.0        131834.45       0
# 165031          565    France    Male  ...             1.0        127429.56       0
# 165032          554     Spain  Female  ...             1.0         71173.03       0
# 165033          850    France    Male  ...             0.0         61581.79       1
#
# [132564 rows x 11 columns]

# %%
cat_features = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
num_features = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary', 'Tenure', 'NumOfProducts']

# %%
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy='most_frequent')),
    ("onehot", OneHotEncoder(handle_unknown="ignore", drop='first', sparse=False))])
numerical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer()),
    # ("scaler", StandardScaler())
])
preprocessor = ColumnTransformer(transformers=[
    ("numerical", numerical_transformer, num_features),
    ("categorical", categorical_transformer, cat_features)])

preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['CreditScore', 'Age', 'Balance',
#                                   'EstimatedSalary', 'Tenure',
#                                   'NumOfProducts']),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['Geography', 'Gender', 'HasCrCard',
#                                   'IsActiveMember'])])

# %%
X = preprocessor.fit_transform(train_f).rename(columns={column: column.split('__')[1] for column in preprocessor.fit_transform(train_f).columns})
y = train_f['Exited']

# %%
X
# Out:
#         CreditScore   Age  ...  HasCrCard_1.0  IsActiveMember_1.0
# 0             668.0  33.0  ...            1.0                 0.0
# 1             627.0  33.0  ...            1.0                 1.0
# 2             678.0  40.0  ...            1.0                 0.0
# 3             581.0  34.0  ...            1.0                 1.0
# 4             716.0  33.0  ...            1.0                 1.0
# ...             ...   ...  ...            ...                 ...
# 165028        630.0  50.0  ...            1.0                 1.0
# 165030        792.0  35.0  ...            0.0                 0.0
# 165031        565.0  31.0  ...            1.0                 1.0
# 165032        554.0  30.0  ...            0.0                 1.0
# 165033        850.0  31.0  ...            1.0                 0.0
#
# [132564 rows x 11 columns]

# %% [markdown]
# # ML

# %% [markdown]
# ## CatBoost

# %%
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    param = {
        "iterations": 2000, # Можно не перебирать, есть Early-Stopping
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100), 
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced"]),
        "depth": trial.suggest_int("depth", 3, 9),
        
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "eval_metric": "AUC", # Тоже стоит заранее определиться

        "objective": trial.suggest_categorical("objective", ["Logloss"]),
    }

    
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        

    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=2024,
        # cat_features=cat_features,
    )

    pruning_callback = CatBoostPruningCallback(trial, "AUC")

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=50,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    y_pred = clf.predict_proba(X_val)[:, 1]
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 5
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    # X_train = train.drop(columns=['outcome'])
    # y_train = train["outcome"]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X, y.astype(str)):
        train_data = X.iloc[train_idx, :], y.iloc[train_idx]
        valid_data = X.iloc[valid_idx, :], y.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
        scores.append(roc_auc_score(valid_data[1], y_pred))
        models.append(model)

    result = np.mean(scores) - np.std(scores)

    if trial.should_prune():
            raise optuna.TrialPruned()
    
    if return_models:
        return result, models
    return result

# %%
study = optuna.create_study(
    study_name="CatBoost",
    direction="maximize",
    pruner=optuna.pruners.HyperbandPruner(
        min_resource=10, max_resource=5000, reduction_factor=10
    ),
    sampler=RandomSampler(2024),
)
study.optimize(objective,
    n_trials=1000,
    n_jobs = -1,
    show_progress_bar=True,
)
# Out:
# [I 2024-01-26 13:41:30,204] A new study created in memory with name: CatBoost
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [I 2024-01-26 13:41:41,892] Trial 29 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:43,306] Trial 22 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:43,437] Trial 1 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:43,674] Trial 28 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:43,957] Trial 19 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:43,960] Trial 4 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:44,410] Trial 0 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:44,664] Trial 11 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:44,672] Trial 3 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:44,678] Trial 23 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:44,732] Trial 26 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:45,143] Trial 10 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:45,169] Trial 17 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:48,072] Trial 9 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:48,165] Trial 14 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:48,185] Trial 18 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:48,494] Trial 32 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:51,005] Trial 34 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:51,776] Trial 35 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:52,031] Trial 44 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41:52,098] Trial 33 pruned. Trial was pruned at iteration 10.
# [I 2024-01-26 13:41
. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:03:55,843] Trial 780 finished with value: 0.9009471350489083 and parameters: {'learning_rate': 0.20635500308756569, 'l2_leaf_reg': 27, 'colsample_bylevel': 0.45660721218176664, 'min_data_in_leaf': 36, 'auto_class_weights': 'Balanced', 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'objective': 'Logloss'}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:03:59,497] Trial 864 pruned. Trial was pruned at iteration 1000.
# [I 2024-01-26 14:04:29,652] Trial 954 pruned. Trial was pruned at iteration 1000.
# [I 2024-01-26 14:04:47,557] Trial 5 finished with value: 0.899232663557916 and parameters: {'learning_rate': 0.10598946716023859, 'l2_leaf_reg': 27, 'colsample_bylevel': 0.4948331341026517, 'min_data_in_leaf': 100, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'objective': 'Logloss', 'bagging_temperature': 14.821629336081404}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:09,090] Trial 326 finished with value: 0.8729546132475274 and parameters: {'learning_rate': 0.010143487793133761, 'l2_leaf_reg': 2, 'colsample_bylevel': 0.5141403846602368, 'min_data_in_leaf': 32, 'auto_class_weights': 'SqrtBalanced', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'objective': 'Logloss', 'bagging_temperature': 16.47061916730653}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:32,446] Trial 728 finished with value: 0.9011227346437444 and parameters: {'learning_rate': 0.11576214529368208, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.43256453536407496, 'min_data_in_leaf': 100, 'auto_class_weights': 'Balanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.7352580665676262}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:33,729] Trial 839 finished with value: 0.9013859927656481 and parameters: {'learning_rate': 0.18187804082679004, 'l2_leaf_reg': 46, 'colsample_bylevel': 0.5155687188966531, 'min_data_in_leaf': 92, 'auto_class_weights': 'Balanced', 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.868562948050949}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:41,290] Trial 842 pruned. Trial was pruned at iteration 1000.
# [I 2024-01-26 14:05:44,740] Trial 853 finished with value: 0.9009473751841411 and parameters: {'learning_rate': 0.22345172247844197, 'l2_leaf_reg': 23, 'colsample_bylevel': 0.5902021604413387, 'min_data_in_leaf': 21, 'auto_class_weights': 'SqrtBalanced', 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'objective': 'Logloss', 'bagging_temperature': 2.0095497345751157}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:46,324] Trial 392 finished with value: 0.9007928356803298 and parameters: {'learning_rate': 0.0529941163518748, 'l2_leaf_reg': 21, 'colsample_bylevel': 0.4710002991838746, 'min_data_in_leaf': 24, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.1979617891294287}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:05:46,410] Trial 299 finished with value: 0.8907870357519005 and parameters: {'learning_rate': 0.0024395893455181395, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.21388118741973802, 'min_data_in_leaf': 13, 'auto_class_weights': 'SqrtBalanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'objective': 'Logloss'}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:06:06,459] Trial 994 finished with value: 0.9007952989407739 and parameters: {'learning_rate': 0.07000110380732547, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.6654831107302975, 'min_data_in_leaf': 36, 'auto_class_weights': 'Balanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.7064984407676538}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:06:09,989] Trial 927 finished with value: 0.9013950662038636 and parameters: {'learning_rate': 0.2776704358779263, 'l2_leaf_reg': 39, 'colsample_bylevel': 0.570485074300011, 'min_data_in_leaf': 91, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.7389978963504087}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:06:22,898] Trial 860 pruned. Trial was pruned at iteration 1000.
# [I 2024-01-26 14:06:29,453] Trial 935 finished with value: 0.9012353071726907 and parameters: {'learning_rate': 0.294675522017001, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.5833207183098732, 'min_data_in_leaf': 54, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.8428624240127963}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:06:41,700] Trial 20 finished with value: 0.8912592016597984 and parameters: {'learning_rate': 0.0013681057888142209, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.5045453781434073, 'min_data_in_leaf': 17, 'auto_class_weights': 'SqrtBalanced', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.7709370967159506}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:07:49,592] Trial 689 finished with value: 0.8955239333550076 and parameters: {'learning_rate': 0.10325533760731687, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.6262349714574255, 'min_data_in_leaf': 7, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'objective': 'Logloss', 'bagging_temperature': 18.475604000065047}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:09:41,858] Trial 425 finished with value: 0.8886687123545383 and parameters: {'learning_rate': 0.010343217028463168, 'l2_leaf_reg': 29, 'colsample_bylevel': 0.5274783152190281, 'min_data_in_leaf': 73, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'objective': 'Logloss', 'subsample': 0.1405345567478707}. Best is trial 352 with value: 0.9014349425685045.
# [I 2024-01-26 14:13:08,944] Trial 177 finished with value: 0.9010243718613509 and parameters: {'learning_rate': 0.006807685374219957, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.43397463320450363, 'min_data_in_leaf': 93, 'auto_class_weights': 'SqrtBalanced', 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'objective': 'Logloss'}. Best is trial 352 with value: 0.9014349425685045.

# %%
{'learning_rate': 0.28032105310060784, 'l2_leaf_reg': 43, 'colsample_bylevel': 0.19416882891868145, 'min_data_in_leaf': 6, 'auto_class_weights': 'SqrtBalanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'objective': 'Logloss'} # 0.9000956693941863.

# %%
study.best_value
# Out:
# 0.9014349425685045

# %%
study.best_params
# Out:
# {'learning_rate': 0.1696310500969717,
#  'l2_leaf_reg': 48,
#  'colsample_bylevel': 0.5868476873585279,
#  'min_data_in_leaf': 25,
#  'auto_class_weights': 'SqrtBalanced',
#  'depth': 5,
#  'boosting_type': 'Ordered',
#  'bootstrap_type': 'Bernoulli',
#  'objective': 'Logloss',
#  'subsample': 0.7402107645449161}

# %% [markdown]
# ## LightGBM

# %%
def fit_lgbm(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val


    param = {
        "objective": "binary",
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 90),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }


    # Add a callback for pruning.
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
    clf = LGBMClassifier(**param, n_jobs=-1, n_estimators=1000, verbose=0, callbacks=[
        pruning_callback,
        early_stopping(100, verbose=0),
    ])
    clf.fit(X_train, y_train, eval_set=[(X_val, y_val)])

    preds = clf.predict_proba(X_val)[:, 1]
    return clf, preds

# %%
def objective(trial, return_models=False):
    n_splits = 5
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    # X_train = train.drop(columns=['outcome'])
    # y_train = train["outcome"]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X, y.astype(str)):
        train_data = X.iloc[train_idx, :], y.iloc[train_idx]
        valid_data = X.iloc[valid_idx, :], y.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_lgbm(trial, train_data, valid_data) # Определили выше
        scores.append(roc_auc_score(valid_data[1], y_pred))
        models.append(model)

    result = np.mean(scores) - np.std(scores)

    if trial.should_prune():
            raise optuna.TrialPruned()
    
    if return_models:
        return result, models
    return result

# %%
study = optuna.create_study(
    study_name="LGBM",
    direction="maximize",
    pruner=optuna.pruners.HyperbandPruner(
        min_resource=10, max_resource=5000, reduction_factor=10
    ),
    sampler=RandomSampler(2024),
)
study.optimize(objective,
    n_trials=1000,
    n_jobs = -1,
    show_progress_bar=True,
)

# %%
study.best_value
# Out:
# 0.9011865697241652

# %%
study.best_params
# Out:
# {'lambda_l1': 2.3772843324101983e-05,
#  'lambda_l2': 3.669720725756965e-07,
#  'num_leaves': 4,
#  'feature_fraction': 0.7574838929544363,
#  'bagging_fraction': 0.7330639363496431,
#  'bagging_freq': 7,
#  'min_child_samples': 51}

# %% [markdown]
# ## XGB

# %%
def fit_xgboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    # dtrain = xgb.DMatrix(X_train, label=y_train)
    # dvalid = xgb.DMatrix(X_val, label=y_val)

    param = {
        "verbosity": 0,
        "verbose_eval": False,
        "eval_metric": "auc",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        "n_estimators": 500,
        "early_stopping_rounds": 50,
    }

    if param["booster"] == "gbtree" or param["booster"] == "dart":
        param["max_depth"] = trial.suggest_int("max_depth", 1, 9)
        param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)
    
    param["objective"] = "binary:hinge"
    

    # Add a callback for pruning.
    clf = XGBClassifier(**param)
    clf.fit(X_train, y_train, eval_set=[(X_val, y_val)])
    # pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-auc")
    # clf = xgb.train(param, dtrain, evals=[(dvalid, "validation")], callbacks=[pruning_callback])

    y_pred = clf.predict_proba(X_val)[:, 1]
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 5
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    # X_train = train.drop(columns=['outcome'])
    # y_train = train["outcome"]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X, y.astype(str)):
        train_data = X.iloc[train_idx, :], y.iloc[train_idx]
        valid_data = X.iloc[valid_idx, :], y.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_xgboost(trial, train_data, valid_data) # Определили выше
        scores.append(roc_auc_score(valid_data[1], y_pred))
        models.append(model)

    result = np.mean(scores) - np.std(scores)

    if trial.should_prune():
        raise optuna.TrialPruned()
    
    if return_models:
        return result, models
    return result

# %%
study = optuna.create_study(
    study_name="XGB",
    direction="maximize",
    pruner=optuna.pruners.HyperbandPruner(
        min_resource=10, max_resource=5000, reduction_factor=10
    ),
    sampler=RandomSampler(2024),
)
study.optimize(objective,
    n_trials=1000,
    n_jobs = -1,
    show_progress_bar=True,
)
# Out:
# [I 2024-01-26 16:00:16,718] A new study created in memory with name: XGB
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [0]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.62365
# [1]	validation_0-auc:0.50000[3]	validation_0-auc:0.50000
#
# [2]	validation_0-auc:0.65297
# [4]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.49991
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.64452
# [0]	validation_0-auc:0.63718
# [2]	validation_0-auc:0.66672[1]	validation_0-auc:0.50000
#
# [6]	validation_0-auc:0.57161
# [1]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.56210
# [8]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50233
# [2]	validation_0-auc:0.49912
# [7]	validation_0-auc:0.63737
# [2]	validation_0-auc:0.61471
# [2]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.62419
# [8]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.64617
# [2]	validation_0-auc:0.50402
# [3]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.67753
# [4]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50407
# [9]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.57979
# [11]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50140
# [5]	validation_0-auc:0.63678
# [5]	validation_0-auc:0.50000[4]	validation_0-auc:0.50000
#
# [12]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.60046
# [5]	validation_0-auc:0.66243
# [13]	validation_0-auc:0.63373
# [0]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.54092[7]	validation_0-auc:0.66778
#
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.53742
# [6]	validation_0-auc:0.59831
# [6]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50084
# [12]	validation_0-auc:0.51377
# [8]	validation_0-auc:0.53168[1]	validation_0-auc:0.50000
#
# [0]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50018
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.65182[16]	validation_0-auc:0.51988
# [1]	validation_0-auc:0.50000
#
# [0]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000[2]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
#
# [13]	validation_0-auc:0.53612
# [2]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.65427
# [8]	validation_0-auc:0.60194
# [2]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50100
# [8]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.52159
# [10]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50582
# [9]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.79846
# [1]	validation_0-auc:0.50000[9]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000[0]	validation_0-auc:0.50000
#
#
# [3]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.52306
# [15]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000[10]	validation_0-auc:0.53401
#
# [0]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.69590
# [0]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.58841
# [2]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000[1]	validation_0-auc:0.50000
#
# [2]	validation_0-auc:0.79785[2]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.51183
# [1]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
#
# [5]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.49946
# [2]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.54634
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50695
# [12]	validation_0-auc:0.50022
# [12]	validation_0-auc:0.51020
# [0]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50434
# [3]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000[2]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
#
# [7]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.55077
# [2]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50202
# [3]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.79718
# [2]	validation_0-auc:0.81314
# [4]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50245
# [22]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000[3]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
#
# [14]	validation_0-auc:0.52965
# [3]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.53204
# [15]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50464
# [1]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.56724
# [9]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000[15]	validation_0-auc:0.56653
#
# [20]	validation_0-auc:0.52207
# [5]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50105
# [10]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000[4]	validation_0-auc:0.50000
#
# [21]	validation_0-auc:0.50000[1]	validation_0-auc:0.50000
#
# [24]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50393
# [7]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50015
# [4]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000[3]	validation_0-auc:0.81450
#
# [4]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.63474
# [22]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.78589
# [4]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.51477
# [17]	validation_0-auc:0.58593
# [11]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50006
# [11]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50795
# [17]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.53405
# [13]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50052[19]	validation_0-auc:0.50000
#
# [12]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50048
# [27]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.68101
# [9]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.65020[20]	validation_0-auc:0.50000
#
# [4]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.61868
# [18]	validation_0-auc:0.54750
# [5]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.53529
# [14]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000[20]	validation_0-auc:0.50456
# [17]	validation_0-auc:0.50000
#
# [5]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.52975
# [20]	validation_0-auc:0.50499
# [14]	validation_0-auc:0.50000[18]	validation_0-auc:0.50000
#
# [21]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50119
# [15]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50055
# [5]	validation_0-auc:0.78211
# [4]	validation_0-auc:0.81039
# [5]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.57353
# [15]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.60313
# [21]	validation_0-auc:0.54497
# [10]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.54205
# [3]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.64875
# [11]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.49995
# [22]	validation_0-auc:0.50109
# [22]	validation_0-auc:0.51725
# [11]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.52539
# [23]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.77151
# [29]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.63307
# [25]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.61007
# [23]	validation_0-auc:0.52823
# [0]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.77794
# [24]	validation_0-auc:0.57662
# [20]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.60705
# [24]	validation_0-auc:0.50597
# [26]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.63163
# [24]	validation_0-auc:0.50000[19]	validation_0-auc:0.50000
#
# [13]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.80726
# [23]	validation_0-auc:0.49998
# [6]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.51446
# [31]	validation_0-auc:0.50186
# [14]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.51667
# [33]	validation_0-auc:0.50079
# [25]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.53055
# [27]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.52194
# [26]	validation_0-auc:0.52654
# [21]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50195
# [27]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50869
# [6]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50727
# [35]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50794
# [7]	validation_0-auc:0.80432
# [28]	validation_0-auc:0.64335
# [6]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.60397
# [7]	validation_0-auc:0.77895
# [25]	validation_0-auc:0.50539
# [36]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.51810[1]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.52143
#
# [35]	validation_0-auc:0.53642
# [7]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.80147
# [8]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.52468
# [28]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.61959
# [28]	validation_0-auc:0.50281
# [31]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50026
# [32]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.59512
# [29]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.58560[7]	validation_0-auc:0.50000
#
# [18]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.54473
# [27]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50098
# [28]	validation_0-auc:0.52213
# [26]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.51943
# [30]	validation_0-auc:0.50254[7]	validation_0-auc:0.50000
#
# [30]	validation_0-auc:0.65747
# [9]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.54690
# [29]	validation_0-auc:0.50601
# [31]	validation_0-auc:0.54468
# [38]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.62280
# [36]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.52228
# [8]	validation_0-auc:0.77895
# [10]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.51915
# [28]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.51430
# [32]	validation_0-auc:0.51091
# [32]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.81260
# [39]	validation_0-auc:0.59768
# [5]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.54743
# [38]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50022
# [33]	validation_0-auc:0.56041
# [40]	validation_0-auc:0.50278
# [29]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.55349
# [8]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.52059
# [39]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.79737
# [11]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.53835
# [35]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.60671
# [34]	validation_0-auc:0.50048
# [40]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.51741
# [41]	validation_0-auc:0.50008
# [21]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.52923
# [33]	validation_0-auc:0.51718
# [35]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.52132
# [41]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.67327
# [23]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.52852
# [8]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50431
# [44]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.51326
# [9]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.52263
# [42]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.53177
# [22]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.51766
# [34]	validation_0-auc:0.52791
# [33]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.49998
# [43]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000[37]	validation_0-auc:0.50000
#
# [8]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.53016
# [45]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.51646
# [34]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50783
# [9]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.53180
# [46]	validation_0-auc:0.58564
# [9]	validation_0-auc:0.50000[44]	validation_0-auc:0.55633
# [9]	validation_0-auc:0.77907
# [9]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
#
# [9]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50953
# [8]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50714
# [36]	validation_0-auc:0.55212
# [35]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.81578
# [40]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50153
# [24]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.52004
# [6]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.79639
# [37]	validation_0-auc:0.50277
# [38]	validation_0-auc:0.53038
# [3]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000[27]	validation_0-auc:0.50000
#
# [39]	validation_0-auc:0.54978
# [48]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50389
# [25]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.53266
# [39]	validation_0-auc:0.50290
# [49]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.55849
# [10]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.65713
# [40]	validation_0-auc:0.52147[28]	validation_0-auc:0.50000
#
# [49]	validation_0-auc:0.50046
# [43]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.49998
# [37]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50917
# [39]	validation_0-auc:0.55452
# [44]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.61820
# [10]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.54495
# [9]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.64088
# [51]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.53054
# [40]	validation_0-auc:0.54512
# [41]	validation_0-auc:0.52404
# [15]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.51880
# [45]	validation_0-auc:0.50823
# [2]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50369
# [10]	validation_0-auc:0.77797
# [10]	validation_0-auc:0.81183
# [27]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50727
# [46]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.52423
# [41]	validation_0-auc:0.53484
# [46]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.50001
# [43]	validation_0-auc:0.58692
# [43]	validation_0-auc:0.55295
# [9]	validation_0-auc:0.79349
# [48]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.53795
# [49]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50275
# [54]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.52830
# [44]	validation_0-auc:0.51945
# [17]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.51506
# [33]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.50627
# [55]	validation_0-auc:0.54489
# [48]	validation_0-auc:0.50167
# [43]	validation_0-auc:0.52353
# [44]	validation_0-auc:0.51478
# [4]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.57542
# [34]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.55276
# [49]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.50007
# [11]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.53217[52]	validation_0-auc:0.50102
# [46]	validation_0-auc:0.51999
# [1]	validation_0-auc:0.50000
#
# [46]	validation_0-auc:0.50857
# [45]	validation_0-auc:0.53176
# [50]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.49998
# [31]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.52481
# [36]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.60061
# [11]	validation_0-auc:0.50000
# [58]	validation_0-auc:0.49998
# [51]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.51188
# [11]	validation_0-auc:0.77236
# [3]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.55994
# [11]	validation_0-auc:0.81209
# [46]	validation_0-auc:0.52916
# [4]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.60211
# [48]	validation_0-auc:0.54383
# [45]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.50434
# [47]	validation_0-auc:0.56493
# [59]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50277
# [0]	validation_0-auc:0.61000
# [47]	validation_0-auc:0.52562
# [10]	validation_0-auc:0.79186
# [49]	validation_0-auc:0.57258
# [6]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.49995
# [37]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.63476[48]	validation_0-auc:0.50327
#
# [0]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.55596
# [55]	validation_0-auc:0.50002
# [11]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.52933
# [5]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.67956
# [8]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.51164
# [1]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.57413
# [56]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.52252
# [50]	validation_0-auc:0.55227
# [48]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.62245[2]	validation_0-auc:0.50000
#
# [51]	validation_0-auc:0.53353
# [12]	validation_0-auc:0.50000[4]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
#
# [49]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.53236
# [11]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000[12]	validation_0-auc:0.77743
#
# [51]	validation_0-auc:0.54825
# [57]	validation_0-auc:0.51867
# [50]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.56611
# [12]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.81228
# [52]	validation_0-auc:0.51199
# [5]	validation_0-auc:0.58317
# [4]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.51903
# [5]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.53795
# [40]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.56590
# [6]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.52350
# [6]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.53435
# [14]	validation_0-auc:0.50000[11]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.57185
#
# [53]	validation_0-auc:0.53981
# [38]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.78962
# [15]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.51782
# [7]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.50833
# [8]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000[39]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.53908
# [18]	validation_0-auc:0.50000
#
# [8]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000[0]	validation_0-auc:0.55349
#
# [9]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [55]	validation_0-auc:0.53755
# [54]	validation_0-auc:0.54557
# [44]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.62397
# [19]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [55]	validation_0-auc:0.54000
# [9]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50507
# [20]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.50151
# [55]	validation_0-auc:0.51071
# [11]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.57962
# [2]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.53499
# [8]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50009
# [13]	validation_0-auc:0.77433
# [41]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.62967
# [13]	validation_0-auc:0.81233
# [12]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.57454
# [9]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.53822
# [14]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [58]	validation_0-auc:0.51184
# [13]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.51860
# [42]	validation_0-auc:0.50000
# [58]	validation_0-auc:0.54333
# [25]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50309
# [48]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.61608
# [59]	validation_0-auc:0.52102[15]	validation_0-auc:0.50000
#
# [12]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [59]	validation_0-auc:0.53655
# [43]	validation_0-auc:0.50000
# [58]	validation_0-auc:0.60523
# [4]	validation_0-auc:0.50019
# [2]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [59]	validation_0-auc:0.51673
# [13]	validation_0-auc:0.50000[27]	validation_0-auc:0.50000
#
# [14]	validation_0-auc:0.50000
# [60]	validation_0-auc:0.55098
# [6]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.78981
# [7]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [60]	validation_0-auc:0.60459
# [50]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [61]	validation_0-auc:0.53995[15]	validation_0-auc:0.65666
# [6]	validation_0-auc:0.50000
#
# [61]	validation_0-auc:0.52986
# [14]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.54691
# [14]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [62]	validation_0-auc:0.55544
# [31]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [62]	validation_0-auc:0.55368
# [14]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [63]	validation_0-auc:0.51663
# [6]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.64092
# [10]	validation_0-auc:0.61774[63]	validation_0-auc:0.54385
#
# [33]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.52159
# [14]	validation_0-auc:0.77416
# [28]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.55194
# [14]	validation_0-auc:0.80918
# [64]	validation_0-auc:0.56387
# [7]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50035
# [64]	validation_0-auc:0.55355
# [22]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50527[48]	validation_0-auc:0.50000
#
# [36]	validation_0-auc:0.50000
# [65]	validation_0-auc:0.52175
# [14]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.49995
# [65]	validation_0-auc:0.55215
# [20]	validation_0-auc:0.67008
# [9]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [66]	validation_0-auc:0.56744
# [14]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.59199
# [24]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50744
# [10]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [67]	validation_0-auc:0.51995
# [66]	validation_0-auc:0.55730
# [4]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.49998
# [25]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.78829
# [0]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [67]	validation_0-auc:0.55446
# [68]	validation_0-auc:0.59952
# [16]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.79040
# [15]	validation_0-auc:0.50000[14]	validation_0-auc:0.53246
# [43]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
#
# [7]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000[17]	validation_0-auc:0.50000
#
# [15]	validation_0-auc:0.50000
# [68]	validation_0-auc:0.56335
# [69]	validation_0-auc:0.52781
# [23]	validation_0-auc:0.61507
# [24]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50018
# [70]	validation_0-auc:0.57594
# [29]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000[14]	validation_0-auc:0.50000
#
# [69]	validation_0-auc:0.55582
# [25]	validation_0-auc:0.65514
# [25]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.77229
# [14]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50154
# [47]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.80825
# [19]	validation_0-auc:0.59707
# [71]	validation_0-auc:0.52907
# [26]	validation_0-auc:0.50124
# [70]	validation_0-auc:0.56997
# [3]	validation_0-auc:0.50000[4]	validation_0-auc:0.50000
#
# [17]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.59007
# [20]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [71]	validation_0-auc:0.55819
# [32]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [72]	validation_0-auc:0.59267
# [21]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50497
# [33]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50292
# [28]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [72]	validation_0-auc:0.57283
# [73]	validation_0-auc:0.53334
# [10]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50891
# [34]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000[18]	validation_0-auc:0.50000
#
# [29]	validation_0-auc:0.57234
# [8]	validation_0-auc:0.50000
# [74]	validation_0-auc:0.55849
# [35]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.69402
# [5]	validation_0-auc:0.50000
# [73]	validation_0-auc:0.56522
# [1]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.66744
# [14]	validation_0-auc:0.78737
# [36]	validation_0-auc:0.50000
# [75]	validation_0-auc:0.53397
# [21]	validation_0-auc:0.50051
# [19]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.52926
# [37]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.59091
# [2]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [74]	validation_0-auc:0.57202
# [34]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50006
# [38]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50725
# [22]	validation_0-auc:0.50009
# [76]	validation_0-auc:0.56100
# [16]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.61970
# [16]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50067
# [35]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.53381
# [77]	validation_0-auc:0.53658
# [40]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50086
# [75]	validation_0-auc:0.57058[8]	validation_0-auc:0.50000
#
# [26]	validation_0-auc:0.66414
# [16]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.57003
# [33]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50059
# [12]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50322
# [16]	validation_0-auc:0.77209
# [16]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50225
# [41]	validation_0-auc:0.50000
# [76]	validation_0-auc:0.57692
# [34]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [78]	validation_0-auc:0.55935
# [28]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.53525
# [2]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50752
# [42]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.52488
# [3]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50009
# [17]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [77]	validation_0-auc:0.57747
# [79]	validation_0-auc:0.53903
# [5]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.51843
# [29]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.80261
# [44]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50155
# [5]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50101
# [11]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [78]	validation_0-auc:0.57949
# [80]	validation_0-auc:0.55969
# [6]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.52427
# [7]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.60181
# [7]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.52459
# [31]	validation_0-auc:0.57856
# [46]	validation_0-auc:0.50000[81]	validation_0-auc:0.54070
# [79]	validation_0-auc:0.58334
#
# [26]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.49993
# [8]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.56964
# [28]	validation_0-auc:0.50009
# [19]	validation_0-auc:0.50455
# [47]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [82]	validation_0-auc:0.55824
# [14]	validation_0-auc:0.50000[9]	validation_0-auc:0.50000
#
# [39]	validation_0-auc:0.50006
# [80]	validation_0-auc:0.58179
# [48]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50825
# [15]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.62433
# [40]	validation_0-auc:0.50047
# [11]	validation_0-auc:0.50000
# [83]	validation_0-auc:0.54162
# [15]	validation_0-auc:0.78677
# [9]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.55414[21]	validation_0-auc:0.50009
# [29]	validation_0-auc:0.50000
#
# [81]	validation_0-auc:0.58633
# [41]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.53722
# [49]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.51655
# [12]	validation_0-auc:0.50000
# [84]	validation_0-auc:0.56542
# [41]	validation_0-auc:0.50009
# [5]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.49995
# [41]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [82]	validation_0-auc:0.58629
# [17]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50684
# [22]	validation_0-auc:0.56124
# [85]	validation_0-auc:0.53359
# [42]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.52169
# [83]	validation_0-auc:0.59022
# [11]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.80811
# [18]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50226
# [17]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50638
# [32]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.49995
# [86]	validation_0-auc:0.58389
# [84]	validation_0-auc:0.59157
# [19]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.77285
# [24]	validation_0-auc:0.57112
# [33]	validation_0-auc:0.50620
# [16]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.80261
# [33]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.68979
# [17]	validation_0-auc:0.50000
# [87]	validation_0-auc:0.54646
# [13]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50152
# [34]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [85]	validation_0-auc:0.59295
# [45]	validation_0-auc:0.53071
# [34]	validation_0-auc:0.50598
# [39]	validation_0-auc:0.62658
# [18]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.49998
# [14]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.64385
# [21]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50035
# [88]	validation_0-auc:0.58020
# [16]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [86]	validation_0-auc:0.59448
# [35]	validation_0-auc:0.50622
# [46]	validation_0-auc:0.50798
# [26]	validation_0-auc:0.64064
# [44]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.56833
# [36]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.59141
# [87]	validation_0-auc:0.59828
# [47]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50500
# [22]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.53597
# [43]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.51154
# [18]	validation_0-auc:0.69019
# [1]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50383
# [23]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.53925
# [44]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [88]	validation_0-auc:0.59878
# [37]	validation_0-auc:0.50807
# [24]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50989
# [25]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.51365
# [16]	validation_0-auc:0.78644
# [18]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.50099
# [89]	validation_0-auc:0.60133
# [0]	validation_0-auc:0.62686
# [45]	validation_0-auc:0.51970
# [26]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50266[1]	validation_0-auc:0.50132
#
# [30]	validation_0-auc:0.52844[25]	validation_0-auc:0.50000[50]	validation_0-auc:0.49995
#
# [46]	validation_0-auc:0.49998
# [27]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
#
# [17]	validation_0-auc:0.50000
# [90]	validation_0-auc:0.60269
# [51]	validation_0-auc:0.53306
# [19]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50660
# [39]	validation_0-auc:0.54968
# [52]	validation_0-auc:0.50013
# [91]	validation_0-auc:0.60433
# [5]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.79872
# [3]	validation_0-auc:0.51174
# [47]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000[30]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
#
# [18]	validation_0-auc:0.77046
# [26]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50308
# [32]	validation_0-auc:0.52661
# [31]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [92]	validation_0-auc:0.60563
# [52]	validation_0-auc:0.57850
# [18]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.60889
# [14]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50009
# [43]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.49986
# [32]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.49986
# [54]	validation_0-auc:0.50146
# [21]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [93]	validation_0-auc:0.60821
# [19]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.66903
# [41]	validation_0-auc:0.59719
# [33]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [55]	validation_0-auc:0.50174
# [44]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [22]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.52940
# [9]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [94]	validation_0-auc:0.60895
# [29]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50443
# [45]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.50010
# [10]	validation_0-auc:0.50000
# [55]	validation_0-auc:0.50007
# [23]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50953
# [7]	validation_0-auc:0.69518
# [95]	validation_0-auc:0.60974
# [17]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.64707
# [11]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.62641
# [24]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [56]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.53493
# [19]	validation_0-auc:0.69019
# [47]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.52495
# [96]	validation_0-auc:0.61138
# [51]	validation_0-auc:0.51048
# [44]	validation_0-auc:0.52518
# [38]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.54044
# [25]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50018
# [31]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [57]	validation_0-auc:0.55824
# [26]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# ...
# [23]	validation_0-auc:0.78176
# [16]	validation_0-auc:0.55407
# [69]	validation_0-auc:0.60068
# [19]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.52726
# [70]	validation_0-auc:0.60238
# [30]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.71308
# [18]	validation_0-auc:0.53098
# [71]	validation_0-auc:0.59941
# [36]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50112
# [26]	validation_0-auc:0.50000
# [72]	validation_0-auc:0.60870
# [41]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.52173
# [42]	validation_0-auc:0.81563
# [73]	validation_0-auc:0.60538
# [21]	validation_0-auc:0.50024
# [74]	validation_0-auc:0.61140
# [23]	validation_0-auc:0.76634
# [22]	validation_0-auc:0.66725
# [47]	validation_0-auc:0.50000
# [75]	validation_0-auc:0.60896
# [37]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.54824
# [76]	validation_0-auc:0.61151
# [24]	validation_0-auc:0.52260
# [48]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [77]	validation_0-auc:0.61555
# [25]	validation_0-auc:0.52847
# [43]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.51188
# [78]	validation_0-auc:0.61379
# [45]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.53943
# [18]	validation_0-auc:0.50000
# [79]	validation_0-auc:0.62112
# [20]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.50578
# [42]	validation_0-auc:0.50000
# [80]	validation_0-auc:0.61881
# [21]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.55332
# [38]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [81]	validation_0-auc:0.62241
# [24]	validation_0-auc:0.78101
# [35]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.51479
# [39]	validation_0-auc:0.78939
# [82]	validation_0-auc:0.62133
# [29]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.54377
# [83]	validation_0-auc:0.62496
# [34]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.51747
# [84]	validation_0-auc:0.62516
# [39]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.56037
# [85]	validation_0-auc:0.62651
# [34]	validation_0-auc:0.50913
# [33]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.71308
# [86]	validation_0-auc:0.62888
# [35]	validation_0-auc:0.61456
# [41]	validation_0-auc:0.50000
# [87]	validation_0-auc:0.62672
# [36]	validation_0-auc:0.52166
# [27]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.78527
# [40]	validation_0-auc:0.50000
# [88]	validation_0-auc:0.63214
# [49]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.55467
# [19]	validation_0-auc:0.50000
# [89]	validation_0-auc:0.63156
# [27]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.51702
# [21]	validation_0-auc:0.50000
# [90]	validation_0-auc:0.63403
# [47]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.55742
# [22]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.53076
# [0]	validation_0-auc:0.63100
# [41]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.55422
# [24]	validation_0-auc:0.79146
# [1]	validation_0-auc:0.52077
# [2]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.52940
# [92]	validation_0-auc:0.73692
# [3]	validation_0-auc:0.50178
# [43]	validation_0-auc:0.56237
# [25]	validation_0-auc:0.78064
# [4]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.53293
# [43]	validation_0-auc:0.81512
# [38]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.56685
# [5]	validation_0-auc:0.67020
# [48]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.53942
# [6]	validation_0-auc:0.53636
# [42]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.57350
# [30]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50024
# [46]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.53473
# [36]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.56700
# [22]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.51159
# [49]	validation_0-auc:0.59536
# [35]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.53326
# [50]	validation_0-auc:0.53898
# [50]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50198
# [51]	validation_0-auc:0.59755
# [37]	validation_0-auc:0.71308
# [52]	validation_0-auc:0.56054
# [28]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.78883
# [53]	validation_0-auc:0.58191
# [12]	validation_0-auc:0.53288
# [28]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.56960
# [44]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50033
# [14]	validation_0-auc:0.59454
# [55]	validation_0-auc:0.58501
# [15]	validation_0-auc:0.51327
# [56]	validation_0-auc:0.57623
# [16]	validation_0-auc:0.52948
# [14]	validation_0-auc:0.78457
# [26]	validation_0-auc:0.78062
# [57]	validation_0-auc:0.58861
# [17]	validation_0-auc:0.50352
# [18]	validation_0-auc:0.53964
# [58]	validation_0-auc:0.58027
# [19]	validation_0-auc:0.50739
# [45]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50000
# [59]	validation_0-auc:0.59539
# [42]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.58078
# [60]	validation_0-auc:0.58421
# [43]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.51529
# [23]	validation_0-auc:0.50000
# [61]	validation_0-auc:0.59377
# [22]	validation_0-auc:0.54263
# [25]	validation_0-auc:0.80117
# [62]	validation_0-auc:0.59592
# [23]	validation_0-auc:0.50748
# [39]	validation_0-auc:0.50000[31]	validation_0-auc:0.50000
#
# [41]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [63]	validation_0-auc:0.60069
# [24]	validation_0-auc:0.52880
# [34]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50130
# [24]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.57107
# [29]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [27]	validation_0-auc:0.50429
# [0]	validation_0-auc:0.61379
# [36]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.51567
# [44]	validation_0-auc:0.81512
# [28]	validation_0-auc:0.58969
# [2]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50763
# [0]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.71308
# [30]	validation_0-auc:0.55697
# [27]	validation_0-auc:0.78045
# [5]	validation_0-auc:0.51369
# [22]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50402
# [6]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.62405
# [42]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.51102
# [41]	validation_0-auc:0.78863
# [24]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.60393
# [48]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.53353
# [9]	validation_0-auc:0.60391
# [10]	validation_0-auc:0.50009
# [36]	validation_0-auc:0.58377
# [15]	validation_0-auc:0.78380
# [11]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.52662
# [12]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.59682
# [32]	validation_0-auc:0.50000
# [13]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.53328
# [14]	validation_0-auc:0.51114
# [40]	validation_0-auc:0.58295
# [44]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.53391
# [26]	validation_0-auc:0.80506
# [23]	validation_0-auc:0.50000
# [16]	validation_0-auc:0.57186
# [50]	validation_0-auc:0.50000
# [17]	validation_0-auc:0.52047
# [43]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.57882
# [18]	validation_0-auc:0.52232
# [30]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.55662
# [19]	validation_0-auc:0.50570
# [28]	validation_0-auc:0.78045
# [44]	validation_0-auc:0.57212
# [20]	validation_0-auc:0.53620
# [39]	validation_0-auc:0.71308
# [30]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.56234
# [38]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.50119
# [46]	validation_0-auc:0.56887
# [22]	validation_0-auc:0.54617
# [25]	validation_0-auc:0.50000
# [93]	validation_0-auc:0.73692
# [47]	validation_0-auc:0.56581
# [23]	validation_0-auc:0.50156
# [24]	validation_0-auc:0.59700
# [26]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.81512
# [48]	validation_0-auc:0.58014
# [25]	validation_0-auc:0.50995
# [26]	validation_0-auc:0.55029
# [0]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.56318
# [27]	validation_0-auc:0.50871
# [50]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.58849
# [45]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.57086
# [48]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.56645
# [43]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.50000
# [33]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50079
# [35]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.59350
# [30]	validation_0-auc:0.69811
# [31]	validation_0-auc:0.54382
# [43]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.57133
# [32]	validation_0-auc:0.53698
# [0]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [54]	validation_0-auc:0.58870
# [49]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.78874
# [33]	validation_0-auc:0.52237
# [1]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50000
# [55]	validation_0-auc:0.58342
# [45]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.52776
# [2]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [35]	validation_0-auc:0.51779
# [29]	validation_0-auc:0.78030
# [2]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.52484
# [0]	validation_0-auc:0.57447
# [1]	validation_0-auc:0.50118
# [37]	validation_0-auc:0.51262
# [16]	validation_0-auc:0.78342
# [2]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.53010
# [3]	validation_0-auc:0.53778
# [41]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50730
# [27]	validation_0-auc:0.80857
# [27]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.51325
# [31]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.50000
# [39]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50015
# [35]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.71308
# [40]	validation_0-auc:0.52798
# [44]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50137
# [41]	validation_0-auc:0.51268
# [7]	validation_0-auc:0.50000
# [42]	validation_0-auc:0.52768
# [8]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50955
# [4]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [9]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.56218
# [10]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50690
# [11]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.58355
# [12]	validation_0-auc:0.50044
# [13]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50000
# [7]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50548
# [47]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50136
# [46]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.58775
# [3]	validation_0-auc:0.50000
# [49]	validation_0-auc:0.55333
# [16]	validation_0-auc:0.60998
# [46]	validation_0-auc:0.81609
# [30]	validation_0-auc:0.78040
# [17]	validation_0-auc:0.50159
# [50]	validation_0-auc:0.57659
# [18]	validation_0-auc:0.50009
# [49]	validation_0-auc:0.50000
# [26]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.55586
# [8]	validation_0-auc:0.50000
# [19]	validation_0-auc:0.50295
# [27]	validation_0-auc:0.50000
# [6]	validation_0-auc:0.50000
# [46]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.78855
# [52]	validation_0-auc:0.57020
# [28]	validation_0-auc:0.50000
# [20]	validation_0-auc:0.50112
# [53]	validation_0-auc:0.55701
# [44]	validation_0-auc:0.50000
# [21]	validation_0-auc:0.54523
# [54]	validation_0-auc:0.57173
# [22]	validation_0-auc:0.50112
# [55]	validation_0-auc:0.55334
# [9]	validation_0-auc:0.50000
# [23]	validation_0-auc:0.66994
# [40]	validation_0-auc:0.50000
# [24]	validation_0-auc:0.57702
# [56]	validation_0-auc:0.57706
# [7]	validation_0-auc:0.50000
# [25]	validation_0-auc:0.52638
# [57]	validation_0-auc:0.55712
# [36]	validation_0-auc:0.50000
# [32]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.71308
# [26]	validation_0-auc:0.56294
# [39]	validation_0-auc:0.50000
# [58]	validation_0-auc:0.58038
# [17]	validation_0-auc:0.78307
# [27]	validation_0-auc:0.50347
# [42]	validation_0-auc:0.50000
# [28]	validation_0-auc:0.54275
# [28]	validation_0-auc:0.81107
# [59]	validation_0-auc:0.55402
# [29]	validation_0-auc:0.50446
# [10]	validation_0-auc:0.50000
# [8]	validation_0-auc:0.50000
# [94]	validation_0-auc:0.73692
# [60]	validation_0-auc:0.59277
# [30]	validation_0-auc:0.53015
# [4]	validation_0-auc:0.50000
# [45]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.50366
# [61]	validation_0-auc:0.56231
# [35]	validation_0-auc:0.50000
# [36]	validation_0-auc:0.50000
# [62]	validation_0-auc:0.59465
# [32]	validation_0-auc:0.60910
# [27]	validation_0-auc:0.50000
# [31]	validation_0-auc:0.78082
# [33]	validation_0-auc:0.50305
# [63]	validation_0-auc:0.57513
# [33]	validation_0-auc:0.50000
# [64]	validation_0-auc:0.59235
# [9]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [34]	validation_0-auc:0.64504
# [35]	validation_0-auc:0.54118
# [28]	validation_0-auc:0.50000
# [65]	validation_0-auc:0.57356
# [36]	validation_0-auc:0.54196
# [29]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.54205
# [47]	validation_0-auc:0.50000
# [38]	validation_0-auc:0.53802
# [66]	validation_0-auc:0.59612
# [39]	validation_0-auc:0.54053
# [67]	validation_0-auc:0.58022
# [45]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.53415
# [68]	validation_0-auc:0.59698
# [41]	validation_0-auc:0.54496
# [45]	validation_0-auc:0.50000
# [12]	validation_0-auc:0.50000
# [10]	validation_0-auc:0.50000
# [69]	validation_0-auc:0.59077
# [42]	validation_0-auc:0.53198
# [70]	validation_0-auc:0.59549
# [48]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.54956
# [50]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.50000
# [71]	validation_0-auc:0.59460
# [5]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.53059
# [72]	validation_0-auc:0.59778
# [33]	validation_0-auc:0.50000
# [40]	validation_0-auc:0.50000
# [11]	validation_0-auc:0.50000
# [47]	validation_0-auc:0.81590
# [45]	validation_0-auc:0.54931
# [28]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [44]	validation_0-auc:0.78844
# [73]	validation_0-auc:0.60004
# [46]	validation_0-auc:0.53302
# [74]	validation_0-auc:0.60103
# [13]	validation_0-auc:0.50000
# [41]	validation_0-auc:0.50000
# [18]	validation_0-auc:0.78303
# [32]	validation_0-auc:0.78042
# [42]	validation_0-auc:0.71308
# [47]	validation_0-auc:0.55442
# [45]	validation_0-auc:0.50000
# [37]	validation_0-auc:0.50000
# [75]	validation_0-auc:0.60233
# [48]	validation_0-auc:0.53555
# [36]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.50000
# [76]	validation_0-auc:0.60476
# [49]	validation_0-auc:0.56163
# [12]	validation_0-auc:0.50000
# [43]	validation_0-auc:0.50000
# [1]	validation_0-auc:0.50000
# [50]	validation_0-auc:0.53925
# [77]	validation_0-auc:0.60190
# [34]	validation_0-auc:0.50000
# [51]	validation_0-auc:0.56849
# [78]	validation_0-auc:0.60776
# [29]	validation_0-auc:0.50000
# [30]	validation_0-auc:0.50000
# [2]	validation_0-auc:0.50000
# [52]	validation_0-auc:0.53767
# [79]	validation_0-auc:0.60978
# [46]	validation_0-auc:0.50000
# [53]	validation_0-auc:0.57616
# [1]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [3]	validation_0-auc:0.50000
# [80]	validation_0-auc:0.61172
# [54]	validation_0-auc:0.54821
# [13]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.81275
# [55]	validation_0-auc:0.57229
# [56]	validation_0-auc:0.55152
# [4]	validation_0-auc:0.50000
# [0]	validation_0-auc:0.63649
# [1]	validation_0-auc:0.51871
# [57]	validation_0-auc:0.57895
# [2]	validation_0-auc:0.50218
# [3]	validation_0-auc:0.50081
# [58]	validation_0-auc:0.56260
# [6]	validation_0-auc:0.50000
# [14]	validation_0-auc:0.50000
# [29]	validation_0-auc:0.50000
# [48]	validation_0-auc:0.50000
# [4]	validation_0-auc:0.50000
# [59]	validation_0-auc:0.57214
# [5]	validation_0-auc:0.50000
# [15]	validation_0-auc:0.50000
# [5]	validation_0-auc:0.50256
