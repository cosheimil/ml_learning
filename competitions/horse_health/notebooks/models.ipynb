# %%
# Data
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder

# Models
from catboost import CatBoostClassifier
from xgboost import XGBClassifier, DMatrix
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
from sklearn.metrics import f1_score

# %%
root_folder = "../data/"
# root_folder = "/kaggle/input/playground-series-s3e22/"

# %%
train = pd.read_csv(root_folder + 'train.csv')
test = pd.read_csv(root_folder + 'test.csv')
sample_submission = pd.read_csv(root_folder + 'sample_submission.csv')

# %%
train.isnull().sum()
# Out:
# Unnamed: 0               0
# surgery                  0
# age                      0
# hospital_number          0
# rectal_temp              0
# pulse                    0
# respiratory_rate         0
# temp_of_extremities      0
# peripheral_pulse         0
# mucous_membrane          0
# capillary_refill_time    0
# pain                     0
# peristalsis              0
# abdominal_distention     0
# nasogastric_tube         0
# nasogastric_reflux       0
# nasogastric_reflux_ph    0
# rectal_exam_feces        0
# abdomen                  0
# packed_cell_volume       0
# total_protein            0
# abdomo_appearance        0
# abdomo_protein           0
# surgical_lesion          0
# lesion_1                 0
# lesion_2                 0
# lesion_3                 0
# outcome                  0
# dtype: int64

# %%
cat_features = train.select_dtypes(include=['object']).columns.tolist()[:-1]
num_features = [i for i in train.columns if i not in cat_features]

# %%
cat_features
# Out:
# ['peristalsis',
#  'abdominal_distention',
#  'nasogastric_tube',
#  'nasogastric_reflux',
#  'nasogastric_reflux_ph',
#  'rectal_exam_feces',
#  'abdomen',
#  'packed_cell_volume',
#  'total_protein',
#  'abdomo_appearance',
#  'abdomo_protein',
#  'surgical_lesion',
#  'lesion_1',
#  'lesion_2',
#  'lesion_3']

# %%
X_train = train.drop(columns=['outcome'])
y_train = train['outcome']

# %%
X_train
# Out:
#       Unnamed: 0   surgery       age  hospital_number  rectal_temp     pulse  \
# 0              0 -0.313086 -0.129621         1.801773    -0.368142  1.093380
# 1              1 -0.310258 -0.890705         0.289582    -1.097830 -1.230314
# 2              2 -0.313226  0.124074         1.389357    -0.124913 -0.455749
# 3              3  3.177363 -1.398095        -0.260306    -0.003299 -1.230314
# 4              4  3.204717 -0.256468        -0.947666     1.091232  1.351568
# ...          ...       ...       ...              ...          ...       ...
# 1230        1230 -0.309218  0.377769         1.698669     1.091232 -1.230314
# 1231        1231 -0.314142 -0.890705        -0.672722     1.212846 -0.713937
# 1232        1232 -0.313319 -0.890705         0.152110     0.604774 -0.713937
# 1233        1233 -0.309559 -0.129621        -0.329042    -0.854601 -1.230314
# 1234        1234 -0.314158 -0.129621        -0.878930     0.361545 -0.713937
#
#       respiratory_rate  temp_of_extremities  peripheral_pulse  \
# 0             0.702421            -0.483319          0.068659
# 1            -1.576449             1.598010         -0.812647
# 2            -1.196638            -0.562072          0.068659
# 3             0.322609            -0.539571          0.383411
# 4            -0.247108            -0.528321         -0.434944
# ...                ...                  ...               ...
# 1230          0.702421             1.673013         -0.812647
# 1231         -1.386544            -0.562072          0.194560
# 1232         -0.911779            -0.580823          2.334874
# 1233          0.797374             1.973025         -0.812647
# 1234         -0.437014            -0.577073          0.194560
#
#       mucous_membrane  ...  rectal_exam_feces       abdomen  \
# 0           -0.298737  ...         more_3_sec     depressed
# 1           -0.298921  ...         more_3_sec     mild_pain
# 2            0.237648  ...         less_3_sec  extreme_pain
# 3           -0.298921  ...         more_3_sec     mild_pain
# 4           -0.705212  ...         less_3_sec         alert
# ...               ...  ...                ...           ...
# 1230        -0.299289  ...         more_3_sec     depressed
# 1231        -0.298737  ...         less_3_sec     mild_pain
# 1232        -0.631608  ...         less_3_sec     mild_pain
# 1233        -0.298737  ...         less_3_sec     mild_pain
# 1234        -0.314378  ...         less_3_sec     mild_pain
#
#      packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0                absent        slight            slight   less_1_liter
# 1                absent      moderate              none   more_1_liter
# 2            hypomotile      moderate            slight           none
# 3            hypomotile      moderate            slight   more_1_liter
# 4            hypomotile          none            slight   less_1_liter
# ...                 ...           ...               ...            ...
# 1230             absent      moderate              none   more_1_liter
# 1231         hypomotile        slight            slight           none
# 1232         hypomotile        slight            slight           none
# 1233         hypomotile        slight              none   more_1_liter
# 1234             absent          none            slight           none
#
#      surgical_lesion       lesion_1       lesion_2 lesion_3
# 0          decreased  distend_small  serosanguious      yes
# 1             absent  distend_small  serosanguious      yes
# 2             absent  distend_large  serosanguious      yes
# 3          decreased  distend_small         cloudy      yes
# 4             normal         normal         cloudy       no
# ...              ...            ...            ...      ...
# 1230          absent  distend_large  serosanguious      yes
# 1231       decreased  distend_small  serosanguious      yes
# 1232       increased           firm         cloudy      yes
# 1233          absent  distend_small         cloudy      yes
# 1234          absent  distend_small          clear      yes
#
# [1235 rows x 27 columns]

# %% [markdown]
# # Catboost

# %%
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    param = {
        "iterations": 500, # Можно не перебирать, есть Early-Stopping
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.1),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),
        
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),
        "depth": trial.suggest_int("depth", 3, 9),
        
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "eval_metric": "TotalF1", # Тоже стоит заранее определиться
    }

    
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        

    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=42,
        cat_features=cat_features,
    )

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=30,
    )

    y_pred = clf.predict(X_val)
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 5
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    # X_train = train.drop(columns=['outcome'])
    # y_train = train["outcome"]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X_train, y_train):
        train_data = X_train.iloc[train_idx, :], y_train.iloc[train_idx]
        valid_data = X_train.iloc[valid_idx, :], y_train.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
        scores.append(f1_score(y_pred, valid_data[1], average='micro'))
        models.append(model)

    result = np.mean(scores) - np.std(scores)

    if trial.should_prune():
            raise optuna.TrialPruned()
    
    if return_models:
        return result, models
    return result

# %%
study = optuna.create_study(direction="maximize",
    pruner=optuna.pruners.HyperbandPruner(
        min_resource=1, max_resource=100, reduction_factor=3
    ),)
study.optimize(objective,
    n_trials=1000,
    n_jobs = -1,
    show_progress_bar=True,
)
# Out:
# [I 2023-09-25 23:25:39,660] A new study created in memory with name: no-name-f143e279-333f-49a2-b19d-ea7a8b88ffba
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [I 2023-09-25 23:25:46,363] Trial 14 finished with value: 0.6199249330842874 and parameters: {'learning_rate': 0.028318665698051332, 'l2_leaf_reg': 20, 'colsample_bylevel': 0.5066725287081372, 'auto_class_weights': 'Balanced', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.339105925205214}. Best is trial 14 with value: 0.6199249330842874.
# [I 2023-09-25 23:25:46,592] Trial 31 finished with value: 0.6483975538963785 and parameters: {'learning_rate': 0.006882014920086926, 'l2_leaf_reg': 45, 'colsample_bylevel': 0.34494368204015263, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4892295021272044}. Best is trial 31 with value: 0.6483975538963785.
# [I 2023-09-25 23:25:49,056] Trial 29 finished with value: 0.6587462955151178 and parameters: {'learning_rate': 0.09594621308224878, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.515569170362249, 'auto_class_weights': 'SqrtBalanced', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.7677677993466876}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:50,314] Trial 8 finished with value: 0.6466476606209256 and parameters: {'learning_rate': 0.018231931462576723, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.1329262594727814, 'auto_class_weights': 'SqrtBalanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 10.596074083816111}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:51,758] Trial 18 finished with value: 0.6543751425366161 and parameters: {'learning_rate': 0.08965499597221029, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.1597676431204333, 'auto_class_weights': 'None', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8497504782377203}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:52,063] Trial 19 finished with value: 0.6479369333727516 and parameters: {'learning_rate': 0.09781681576227194, 'l2_leaf_reg': 30, 'colsample_bylevel': 0.2978387594536903, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:54,267] Trial 11 finished with value: 0.6135466439448085 and parameters: {'learning_rate': 0.05056976817620897, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.7453169014830486, 'auto_class_weights': 'Balanced', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.9565456580552394}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:54,338] Trial 9 finished with value: 0.64920046626406 and parameters: {'learning_rate': 0.0012343434613120824, 'l2_leaf_reg': 29, 'colsample_bylevel': 0.3791947392137874, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.809109475807596}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:56,435] Trial 6 finished with value: 0.6299595141700405 and parameters: {'learning_rate': 0.02048094295728754, 'l2_leaf_reg': 43, 'colsample_bylevel': 0.35385671796730206, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:57,143] Trial 22 finished with value: 0.6194084188756881 and parameters: {'learning_rate': 0.09696865510921965, 'l2_leaf_reg': 29, 'colsample_bylevel': 0.2716067227115499, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 14.643583524229083}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:58,449] Trial 13 finished with value: 0.5918631610749789 and parameters: {'learning_rate': 0.07075174008643839, 'l2_leaf_reg': 48, 'colsample_bylevel': 0.08496720870791315, 'auto_class_weights': 'None', 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 13.720690011437764}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:58,681] Trial 26 finished with value: 0.6561381386110724 and parameters: {'learning_rate': 0.019473168615710915, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.07350280667276536, 'auto_class_weights': 'SqrtBalanced', 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.2490069278545315}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:25:59,236] Trial 32 finished with value: 0.6387167054764565 and parameters: {'learning_rate': 0.05938316057287822, 'l2_leaf_reg': 14, 'colsample_bylevel': 0.21748475487022906, 'auto_class_weights': 'Balanced', 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8594669771335957}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:00,081] Trial 15 finished with value: 0.6457327042154025 and parameters: {'learning_rate': 0.0055068748714276715, 'l2_leaf_reg': 27, 'colsample_bylevel': 0.3219029925503577, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:00,202] Trial 36 finished with value: 0.6219322032856024 and parameters: {'learning_rate': 0.0248629709503787, 'l2_leaf_reg': 16, 'colsample_bylevel': 0.3777117358528057, 'auto_class_weights': 'Balanced', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.796199485761976}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:00,563] Trial 34 finished with value: 0.605936213498741 and parameters: {'learning_rate': 0.017504392488106254, 'l2_leaf_reg': 6, 'colsample_bylevel': 0.16654532378447462, 'auto_class_weights': 'None', 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.373989501043353}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:01,178] Trial 0 finished with value: 0.6453364913985471 and parameters: {'learning_rate': 0.06511796540724125, 'l2_leaf_reg': 32, 'colsample_bylevel': 0.5584000069121279, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3514794306874661}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:01,682] Trial 7 finished with value: 0.642449240621125 and parameters: {'learning_rate': 0.07034864385272144, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.7755583531848295, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5654129556642457}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:01,685] Trial 25 finished with value: 0.6375348040499704 and parameters: {'learning_rate': 0.03526082391179432, 'l2_leaf_reg': 16, 'colsample_bylevel': 0.3750977158995498, 'auto_class_weights': 'Balanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:01,714] Trial 16 finished with value: 0.6288719544979607 and parameters: {'learning_rate': 0.016406065119490148, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.6324476268104323, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:02,503] Trial 23 finished with value: 0.6295321736511182 and parameters: {'learning_rate': 0.042418952295356124, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.1383850112524967, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 19.040692011868565}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:02,752] Trial 43 finished with value: 0.4631578947368421 and parameters: {'learning_rate': 0.043356328642179864, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.017603374795450336, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.23337264868743635}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:03,337] Trial 33 finished with value: 0.648278025476472 and parameters: {'learning_rate': 0.07120651971879029, 'l2_leaf_reg': 11, 'colsample_bylevel': 0.19726583400820735, 'auto_class_weights': 'None', 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 11.351063036582527}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:03,850] Trial 42 finished with value: 0.5528255919064085 and parameters: {'learning_rate': 0.08347457592779702, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.02639766133584409, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.8456983011076353}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:04,022] Trial 21 finished with value: 0.6414362571150326 and parameters: {'learning_rate': 0.03643159735921035, 'l2_leaf_reg': 27, 'colsample_bylevel': 0.7615576559068565, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.2658616669172642}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:04,201] Trial 4 finished with value: 0.635492785217973 and parameters: {'learning_rate': 0.02009692437789328, 'l2_leaf_reg': 35, 'colsample_bylevel': 0.16370729412431437, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5024664632157797}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:04,939] Trial 41 finished with value: 0.6574650990376315 and parameters: {'learning_rate': 0.07415644201310206, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.5506444834312986, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7372980771344892}. Best is trial 29 with value: 0.6587462955151178.
# [I 2023-09-25 23:26:05,499] Trial 40 finished with value: 0.6596768377653139 and parameters: {'learning_rate': 0.07223722687520213, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.7923897984567122, 'auto_class_weights': 'None', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6487381845437202}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:05,567] Trial 38 finished with value: 0.6558511718389463 and parameters: {'learning_rate': 0.06925474376788521, 'l2_leaf_reg': 48, 'colsample_bylevel': 0.27236150640035184, 'auto_class_weights': 'None', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:05,571] Trial 30 finished with value: 0.6589855684941068 and parameters: {'learning_rate': 0.08194472926978383, 'l2_leaf_reg': 22, 'colsample_bylevel': 0.5313469732503405, 'auto_class_weights': 'None', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:06,530] Trial 37 finished with value: 0.6532797550732926 and parameters: {'learning_rate': 0.09848582552391602, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.39393137635848097, 'auto_class_weights': 'Balanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.529830316123367}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:06,644] Trial 20 finished with value: 0.6383345247798694 and parameters: {'learning_rate': 0.0520663355046306, 'l2_leaf_reg': 37, 'colsample_bylevel': 0.6905888086819771, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:06,963] Trial 5 finished with value: 0.64713961709993 and parameters: {'learning_rate': 0.05025080721025248, 'l2_leaf_reg': 44, 'colsample_bylevel': 0.7792333015012475, 'auto_class_weights': 'None', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6941753923184893}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:07,834] Trial 1 finished with value: 0.6409121286128012 and parameters: {'learning_rate': 0.04726746107677865, 'l2_leaf_reg': 17, 'colsample_bylevel': 0.7399041415839425, 'auto_class_weights': 'Balanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6522441813776447}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:08,449] Trial 24 finished with value: 0.6188703097793148 and parameters: {'learning_rate': 0.03598410486593246, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.7807111636506334, 'auto_class_weights': 'Balanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.5553815570230904}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:08,648] Trial 35 finished with value: 0.6302906243902076 and parameters: {'learning_rate': 0.04891645723595967, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.6784853607028688, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 13.607369742723048}. Best is trial 40 with value: 0.6596768377653139.
# [I 2023-09-25 23:26:09,004] Trial 10 finished with value: 0.6486897227064591 and parameters: {'learning_rate': 0.04291152157369038, 'l2_leaf_reg': 23, 'colsample_bylevel': 0.6457365998914129, 'auto_class_weights': 'Balanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2715751796531217}. Best is trial 40 with value: 0.6596768377653139.

# %% [markdown]
# # XGBoost

# %%
y_train_encoded = LabelEncoder().fit_transform(y_train)

# %%
def fit_xgboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    dtrain = DMatrix(data=X_train, label=y_train, nthread=-1, enable_categorical=True)
    dtest = DMatrix(data=X_val, label=y_val, nthread=-1, enable_categorical=True)
    evallist = [(dtest, 'eval'), (dtrain, 'train')]

    # param = {
    #     'lambda': trial.suggest_float('lambda', 1e-3, 10.0),
    #     'alpha': trial.suggest_float('alpha', 1e-3, 10.0),
    #     'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
    #     'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
    #     'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.01,0.012,0.014,0.016,0.018, 0.02]),
    #     'n_estimators': 1000,
    #     'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17]),
    #     'random_state': trial.suggest_categorical('random_state', [2020]),
    #     'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    #     'booster': 'dart',
    #     'sample_type': 'uniform',
    #     'rate_drop': '0.1',
    #     'enable_categorical': True,
    # }

    params = {
        'max_depth': trial.suggest_int('max_depth', 1, 9),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
        'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
        'eval_metric': 'mlogloss',
        'use_label_encoder': False
    }

    xgb.train(params, dtrain, 100, evallist)

    clf.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100, verbose=False)

    
    y_pred = clf.predict(X_val)
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 5
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    # X_train = train.drop(columns=['outcome'])
    # y_train = train["outcome"]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X_train, y_train_encoded):
        train_data = X_train.iloc[train_idx, :], y_train_encoded[train_idx]
        valid_data = X_train.iloc[valid_idx, :], y_train_encoded[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_xgboost(trial, train_data, valid_data) # Определили выше
        scores.append(f1_score(y_pred, valid_data[1], average='micro'))
        models.append(model)

    result = np.mean(scores) - np.std(scores)

    if trial.should_prune():
            raise optuna.TrialPruned()
    
    if return_models:
        return result, models
    return result

# %%
study = optuna.create_study(direction="maximize",
    pruner=optuna.pruners.HyperbandPruner(
        min_resource=1, max_resource=100, reduction_factor=3
    ),)
study.optimize(objective,
    n_trials=1000,
    n_jobs = -1,
    show_progress_bar=True,
)
# Out:
# [I 2023-09-25 23:34:22,189] A new study created in memory with name: no-name-cff7da93-d72d-4493-826e-715fd2a95ad8
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# /home/artem/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /tmp/ipykernel_630665/4248517358.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'subsample': trial.suggest_loguniform('subsample', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'colsample_bytree': trial.suggest_loguniform('colsample_bytree', 0.01, 1.0),
# /tmp/ipykernel_630665/4248517358.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
# /tmp/ipykernel_630665/4248517358.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0),
# ...
# [W 2023-09-25 23:34:22,645] Trial 26 failed with value None.
# [W 2023-09-25 23:34:22,647] Trial 31 failed with value None.
# [W 2023-09-25 23:34:22,662] Trial 27 failed with value None.
# [W 2023-09-25 23:34:22,666] Trial 30 failed with value None.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 5
#       1 study = optuna.create_study(direction="maximize",
#       2     pruner=optuna.pruners.HyperbandPruner(
#       3         min_resource=1, max_resource=100, reduction_factor=3
#       4     ),)
# ----> 5 study.optimize(objective,
#       6     n_trials=1000,
#       7     n_jobs = -1,
#       8     show_progress_bar=True,
#       9 )
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/optuna/study/study.py:442, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     339 def optimize(
#     340     self,
#     341     func: ObjectiveFuncType,
#    (...)
#     348     show_progress_bar: bool = False,
#     349 ) -> None:
#     350     """Optimize an objective function.
#     351
#     352     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     440             If nested invocation of this method occurs.
#     441     """
# --> 442     _optimize(
#     443         study=self,
#     444         func=func,
#     445         n_trials=n_trials,
#     446         timeout=timeout,
#     447         n_jobs=n_jobs,
#     448         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     449         callbacks=callbacks,
#     450         gc_after_trial=gc_after_trial,
#     451         show_progress_bar=show_progress_bar,
#     452     )
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:103, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     101                     # Raise if exception occurred in executing the completed futures.
#     102                     for f in completed:
# --> 103                         f.result()
#     105                 futures.add(
#     106                     executor.submit(
#     107                         _optimize_sequential,
#    (...)
#     118                     )
#     119                 )
#     120 finally:
#
# File /nix/store/lx8vhp4fxclp494svlfis3sb2g8z4l9h-python3-3.10.12/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /nix/store/lx8vhp4fxclp494svlfis3sb2g8z4l9h-python3-3.10.12/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /nix/store/lx8vhp4fxclp494svlfis3sb2g8z4l9h-python3-3.10.12/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[40], line 14, in objective(trial, return_models)
#      11 valid_data = X_train.iloc[valid_idx, :], y_train_encoded[valid_idx]
#      13 # Подаем trials для перебора
# ---> 14 model, y_pred = fit_xgboost(trial, train_data, valid_data) # Определили выше
#      15 scores.append(f1_score(y_pred, valid_data[1], average='micro'))
#      16 models.append(model)
#
# Cell In[39], line 36, in fit_xgboost(trial, train, val)
#      21 params = {
#      22     'max_depth': trial.suggest_int('max_depth', 1, 9),
#      23     'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1.0),
#    (...)
#      32     'use_label_encoder': False
#      33 }
#      35 clf = XGBClassifier(**params)
# ---> 36 clf.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100, verbose=False)
#      39 y_pred = clf.predict(X_val)
#      40 return clf, y_pred
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:1496, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1485     params["num_class"] = self.n_classes_
#    1487 (
#    1488     model,
#    1489     metric,
#    (...)
#    1494     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1495 )
# -> 1496 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1497     missing=self.missing,
#    1498     X=X,
#    1499     y=y,
#    1500     group=None,
#    1501     qid=None,
#    1502     sample_weight=sample_weight,
#    1503     base_margin=base_margin,
#    1504     feature_weights=feature_weights,
#    1505     eval_set=eval_set,
#    1506     sample_weight_eval_set=sample_weight_eval_set,
#    1507     base_margin_eval_set=base_margin_eval_set,
#    1508     eval_group=None,
#    1509     eval_qid=None,
#    1510     create_dmatrix=self._create_dmatrix,
#    1511     enable_categorical=self.enable_categorical,
#    1512     feature_types=self.feature_types,
#    1513 )
#    1515 self._Booster = train(
#    1516     params,
#    1517     train_dmatrix,
#    (...)
#    1526     callbacks=callbacks,
#    1527 )
#    1529 if not callable(self.objective):
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:534, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     514 def _wrap_evaluation_matrices(
#     515     missing: float,
#     516     X: Any,
#    (...)
#     530     feature_types: Optional[FeatureTypes],
#     531 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     532     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     533     way."""
# --> 534     train_dmatrix = create_dmatrix(
#     535         data=X,
#     536         label=y,
#     537         group=group,
#     538         qid=qid,
#     539         weight=sample_weight,
#     540         base_margin=base_margin,
#     541         feature_weights=feature_weights,
#     542         missing=missing,
#     543         enable_categorical=enable_categorical,
#     544         feature_types=feature_types,
#     545         ref=None,
#     546     )
#     548     n_validation = 0 if eval_set is None else len(eval_set)
#     550     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:954, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     952 if _can_use_qdm(self.tree_method) and self.booster != "gblinear":
#     953     try:
# --> 954         return QuantileDMatrix(
#     955             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#     956         )
#     957     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     958         pass
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:1528, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#    1508     if any(
#    1509         info is not None
#    1510         for info in (
#    (...)
#    1521         )
#    1522     ):
#    1523         raise ValueError(
#    1524             "If data iterator is used as input, data like label should be "
#    1525             "specified as batch argument."
#    1526         )
# -> 1528 self._init(
#    1529     data,
#    1530     ref=ref,
#    1531     label=label,
#    1532     weight=weight,
#    1533     base_margin=base_margin,
#    1534     group=group,
#    1535     qid=qid,
#    1536     label_lower_bound=label_lower_bound,
#    1537     label_upper_bound=label_upper_bound,
#    1538     feature_weights=feature_weights,
#    1539     feature_names=feature_names,
#    1540     feature_types=feature_types,
#    1541     enable_categorical=enable_categorical,
#    1542 )
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:1587, in QuantileDMatrix._init(self, data, ref, enable_categorical, **meta)
#    1575 config = make_jcargs(
#    1576     nthread=self.nthread, missing=self.missing, max_bin=self.max_bin
#    1577 )
#    1578 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1579     None,
#    1580     it.proxy.handle,
#    (...)
#    1585     ctypes.byref(handle),
#    1586 )
# -> 1587 it.reraise()
#    1588 # delay check_call to throw intermediate exception first
#    1589 _check_call(ret)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:575, in DataIter.reraise(self)
#     573 exc = self._exception
#     574 self._exception = None
# --> 575 raise exc
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:556, in DataIter._handle_exception(self, fn, dft_ret)
#     553     return dft_ret
#     555 try:
# --> 556     return fn()
#     557 except Exception as e:  # pylint: disable=broad-except
#     558     # Defer the exception in order to return 0 and stop the iteration.
#     559     # Exception inside a ctype callback function has no effect except
#     560     # for printing to stderr (doesn't stop the execution).
#     561     tb = sys.exc_info()[2]
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:640, in DataIter._next_wrapper.<locals>.<lambda>()
#     637     self._data_ref = ref
#     639 # pylint: disable=not-callable
# --> 640 return self._handle_exception(lambda: self.next(input_data), 0)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:1260, in SingleBatchInternalIter.next(self, input_data)
#    1258     return 0
#    1259 self.it += 1
# -> 1260 input_data(**self.kwargs)
#    1261 return 1
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/core.py:623, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     621     new, cat_codes, feature_names, feature_types = self._temporary_data
#     622 else:
# --> 623     new, cat_codes, feature_names, feature_types = _proxy_transform(
#     624         data,
#     625         feature_names,
#     626         feature_types,
#     627         self._enable_categorical,
#     628     )
#     629 # Stage the data, meta info are copied inside C++ MetaInfo.
#     630 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:1295, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1293     data = pd.DataFrame(data)
#    1294 if _is_pandas_df(data):
# -> 1295     arr, feature_names, feature_types = _transform_pandas_df(
#    1296         data, enable_categorical, feature_names, feature_types
#    1297     )
#    1298     arr, _ = _ensure_np_dtype(arr, arr.dtype)
#    1299     return arr, None, feature_names, feature_types
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:467, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     460 for dtype in data.dtypes:
#     461     if not (
#     462         (dtype.name in _pandas_dtype_mapper)
#     463         or is_sparse(dtype)
#     464         or (is_categorical_dtype(dtype) and enable_categorical)
#     465         or is_pa_ext_dtype(dtype)
#     466     ):
# --> 467         _invalid_dataframe_dtype(data)
#     468     if is_pa_ext_dtype(dtype):
#     469         pyarrow_extension = True
#
# File ~/projects/ml_learning/competitions/horse_health/.venv/lib/python3.10/site-packages/xgboost/data.py:308, in _invalid_dataframe_dtype(data)
#     306 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     307 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 308 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:peristalsis: object, abdominal_distention: object, nasogastric_tube: object, nasogastric_reflux: object, nasogastric_reflux_ph: object, rectal_exam_feces: object, abdomen: object, packed_cell_volume: object, total_protein: object, abdomo_appearance: object, abdomo_protein: object, surgical_lesion: object, lesion_1: object, lesion_2: object, lesion_3: object
